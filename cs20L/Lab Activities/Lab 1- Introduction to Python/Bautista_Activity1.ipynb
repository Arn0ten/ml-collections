# %%
while True:
    productName = input("Enter product name: ")
    items = int(input("Enter number of items: "))
    price = float(input("Enter price per item: "))
    sold = int(input("Enter items sold: "))

    # Discount 10% in > 20 sales
    totalValueSale = sold * price
    discount = totalValueSale * 0.1
    left = items - sold


    print("\nProduct name:", productName)
    print("Total Items sold:", sold)
    print("Total Items left:", left)
    print("Total Sales without discount: ", totalValueSale)


    anotherProduct = input("Do you want to input another product? (yes/no): \n Note: 1 = yes 0 = no ")
    if anotherProduct != '1':
        break

print("Exits")
# Out:
# Enter product name: TIde
# Enter number of items: 30
# Enter price per item: 10.50
# Enter items sold: 10
#
# Product name: TIde
# Total Items sold: 10
# Total Items left: 20
# Total Sales without discount:  105.0
# Do you want to input another product? (yes/no):
#  Note: 1 = yes 0 = no 1
# Enter product name: barko
# Enter number of items: 60
# Enter price per item: 9000
# Enter items sold: 40
#
# Product name: barko
# Total Items sold: 40
# Total Items left: 20
# Total Sales without discount:  360000.0
# Do you want to input another product? (yes/no):
#  Note: 1 = yes 0 = no 0
# Exits
