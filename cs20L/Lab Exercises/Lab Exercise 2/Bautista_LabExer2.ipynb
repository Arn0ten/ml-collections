# %%
#Activity 2.
#Step 1
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

df2= pd.read_csv('Data.csv')
print(df2)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#Step 2
x = df2.iloc[:, :-1].values
y = df2.iloc[:, -1].values

# %%
print(x)
# Out:
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 nan]
#  ['France' 35.0 58000.0]
#  ['Spain' nan 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]

# %%
print(y)
# Out:
# [88. 90. 93. nan 84. 86. 91. 93. 84. 91. 78. 86. 75. 84. 95.]

# %%
#Step 3
df2.isna()
# Out:
#    Country    Age  Salary  Purchased
# 0    False  False   False      False
# 1    False  False   False      False
# 2    False  False   False      False
# 3    False  False   False      False
# 4    False  False    True      False
# 5    False  False   False      False
# 6    False   True   False      False
# 7    False  False   False      False
# 8    False  False   False      False
# 9    False  False   False      False

# %%
#Step 4
df2.isna().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
#Step 5
df2.isna().sum().sum()
# Out:
# 2

# %%
#Step 6
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
#Step 7
imputer.fit(x[:,1:3])
x[:,1:3] = imputer.transform(x[:,1:3])

# %%
#Step 8
x[:, 1:3] = imputer.transform(x[:, 1:3])

# %%
#Step 9
print(x)
# Out:
# [['Harry Potter' 85 92.0 90 92.0]
#  ['Hermione Granger' 91 90.0 86 95.0]
#  ['Ron Weasley' 92 86.0 88 89.0]
#  ['Draco Malfoy' 84 80.0 82 84.0]
#  ['Neville Longbottom' 89 84.0 84 85.0]
#  ['Dean Thomas' 84 84.0 88 nan]
#  ['Seamus Finnigan' 91 86.0 86 87.0]
#  ['Lavender Brown' 83 83.0 92 90.0]
#  ['Fred Weasley' 90 80.0 85 88.0]
#  ['Oliver Wood' 76 nan 84 86.0]
#  ['Katie Bell' 75 88.0 82 85.0]
#  ['Parvati Patil' 90 85.0 78 87.0]
#  ['Romilda Vane' 75 78.0 80 85.0]
#  ['Luna Lovegood' 80 81.0 85 83.0]
#  ['Alicia Spinnet' 95 84.0 80 90.0]]

# %% [markdown]
# **ACTIVITY1**. using the harry pooter dataset, print and identify the missing values
#   1. Using imputer, fill the missing values.
#   2. Update your dataset, print the updated values (With no NaNs)

# %%
#Activity 1.
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# Step 1: Load the dataset
df = pd.read_csv('HarryPotterGrades Dataset with Null.csv')
print(df)
# Out:
#                   Name  Potions  Defense Against the Dark Arts  \
# 0         Harry Potter       85                           92.0
# 1     Hermione Granger       91                           90.0
# 2          Ron Weasley       92                           86.0
# 3         Draco Malfoy       84                           80.0
# 4   Neville Longbottom       89                           84.0
# 5          Dean Thomas       84                           84.0
# 6      Seamus Finnigan       91                           86.0
# 7       Lavender Brown       83                           83.0
# 8         Fred Weasley       90                           80.0
# 9          Oliver Wood       76                            NaN
# 10          Katie Bell       75                           88.0
# 11       Parvati Patil       90                           85.0
# 12        Romilda Vane       75                           78.0
# 13       Luna Lovegood       80                           81.0
# ...

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
#Identify the missing values
print(df.isna())
# Out:
#      Name  Potions  Defense Against the Dark Arts  Care of Magical Creatures  \
# 0   False    False                          False                      False
# 1   False    False                          False                      False
# 2   False    False                          False                      False
# 3   False    False                          False                      False
# 4   False    False                          False                      False
# 5   False    False                          False                      False
# 6   False    False                          False                      False
# 7   False    False                          False                      False
# 8   False    False                          False                      False
# 9   False    False                           True                      False
# 10  False    False                          False                      False
# ...

# %%
print(df.isnull().sum())
# Out:
# Name                             0
# Potions                          0
# Defense Against the Dark Arts    1
# Care of Magical Creatures        0
# Transfiguration                  1
# Herbology                        1
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 3

# %%
# prompt: #1.Using imputer, fill in the missing values.Update your dataset, print the updated values(with no NaNs)
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(df.iloc[:, 1:6])
df.iloc[:, 1:6] = imputer.transform(df.iloc[:, 1:6])
print(x)
# Out:
# [['Harry Potter' 85.0 92.0 90 92.0]
#  ['Hermione Granger' 91.0 90.0 86 95.0]
#  ['Ron Weasley' 92.0 86.0 88 89.0]
#  ['Draco Malfoy' 84.0 80.0 82 84.0]
#  ['Neville Longbottom' 89.0 84.0 84 85.0]
#  ['Dean Thomas' 84.0 84.0 88 nan]
#  ['Seamus Finnigan' 91.0 86.0 86 87.0]
#  ['Lavender Brown' 83.0 83.0 92 90.0]
#  ['Fred Weasley' 90.0 80.0 85 88.0]
#  ['Oliver Wood' 76.0 84.35714285714286 84 86.0]
#  ['Katie Bell' 75.0 88.0 82 85.0]
#  ['Parvati Patil' 90.0 85.0 78 87.0]
#  ['Romilda Vane' 75.0 78.0 80 85.0]
#  ['Luna Lovegood' 80.0 81.0 85 83.0]
#  ['Alicia Spinnet' 95.0 84.0 80 90.0]]
